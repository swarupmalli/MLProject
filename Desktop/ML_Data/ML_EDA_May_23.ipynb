# %%
## Imports

from __future__ import print_function
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.display import display

from scipy import stats
import matplotlib.pyplot as plt


plt.style.use('ggplot')


pd.set_option('display.max_columns', None)

# %%
# Data import
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')
df = train.copy()
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# All Numerical Features
num = df.select_dtypes(include = [np.number])

#All NaN Numerical Features
num.isnull().sum().sort_values(ascending = False)


num.isnull().sum()
# Changing NA to '0' for LotFrontage
num['LotFrontage'] = num['LotFrontage'].fillna(0)


# Changing NA to '0' for MasVnrArea
num['MasVnrArea'] = num['MasVnrArea'].fillna(0)

# All LotArea < 50000
lot_area = num.loc[num['LotArea']< 50000]
# Out:
# /Users/ElinaMac/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/ElinaMac/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
garage_na = num.loc[num['GarageYrBlt'].isnull()]
garage_na
garage_2 = num.loc[num['GarageYrBlt']!= num['YearBuilt']] 

# dropping GarageYrBlt from df
df.drop('GarageYrBlt', axis = 1, inplace=True)

# %%
plt.scatter(x = num.GarageYrBlt, y = num.SalePrice, color = 'b')

# %%
# All Categorical Features
categ = df.select_dtypes(exclude = [np.number])
#All NaN Categorical Features
categ.isnull().sum().sort_values(ascending = False)
categ.isna().sum().sort_values(ascending = False)


# Changing NA to 'None' for MasVnrType
df['MasVnrType'] = df['MasVnrType'].fillna('None')

# %%
categ.isnull().sum().sort_values(ascending = False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# GarageCond         81
# GarageQual         81
# GarageFinish       81
# GarageType         81
# BsmtFinType2       38
# BsmtExposure       38
# BsmtFinType1       37
# BsmtQual           37
# BsmtCond           37
# MasVnrType          8
# Electrical          1
# Condition2          0
# Condition1          0
# Neighborhood        0
# LandSlope           0
# BldgType            0
# LandContour         0
# LotConfig           0
# Utilities           0
# RoofStyle           0
# LotShape            0
# Street              0
# HouseStyle          0
# SaleCondition       0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# ExterQual           0
# ExterCond           0
# Foundation          0
# SaleType            0
# Heating             0
# HeatingQC           0
# CentralAir          0
# KitchenQual         0
# Functional          0
# ...

# %%
categ['BsmtFinType2'].unique()
# Out:
# array(['Unf', 'BLQ', nan, 'ALQ', 'Rec', 'LwQ', 'GLQ'], dtype=object)

# %% [markdown]
# # Continue from this point

# %% [markdown]
# ## Basement related variables - missing values

# %% [markdown]
# Check everything Basement related, there are 5 columns to check: 3 have 37 missing values, 2 have 38 missing values. The difference is due to one house having BsmtQual: Gd (Good), BsmtCond: TA (Typical), BsmtExposure: No (No exposure but there is a basement(???)) , BsmtFinType1: GLQ (Good living quarters)

# %%
categ[categ['BsmtFinType2'].isnull()]
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 17         RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 39         RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 90         RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 102        RL   Pave   NaN      Reg         Bnk    AllPub    Inside       Gtl
# 156        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 182        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 259        RM   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 332        RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 342        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 362        RL   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 371        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# ...

# %% [markdown]
# Check with numerical Basement-related columns: BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF

# %%
# df[df.TotalBsmtSF == 0]



df[df.TotalBsmtSF == 0].shape[0]
# Out:
# 37

# %%
df[df.BsmtFinType2 == 'Unf']
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
# ...

# %% [markdown]
# So there are 37 houses with no basement.

# %%
bsmt_var = [x for x in df if 'Bsmt' in x]
for x in bsmt_var:
    df[x] = df[x].fillna('NoBsmt')

# %% [markdown]
# Thus only one value for BsmtFinType2 is truly missing. It's a house with 'Id' = 332. The rest should be imputed with 'NoBsmt'. The imputation should be done for BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1: ('NaN' to 'NoBsmt')

# %% [markdown]
# We impute the value with 'Unf':

# %% [markdown]
# ## Garage related variables - missing values

# %%
garage_var = [x for x in df if 'Garage' in x]
for x in garage_var:
    df[x] = df[x].fillna('NoG')

# %% [markdown]
# ## Pool - missing values

# %%
df['PoolArea'].value_counts()
# Out:
# 0      1453
# 738       1
# 648       1
# 576       1
# 555       1
# 519       1
# 512       1
# 480       1
# Name: PoolArea, dtype: int64

# %%
df['PoolQC'] = df['PoolQC'].fillna('NoP')

# %%
categ = df.select_dtypes(exclude = [np.number])
categ.isnull().sum().sort_values(ascending = False)
# Out:
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# Electrical          1
# SaleCondition       0
# Condition1          0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# HouseStyle          0
# BldgType            0
# Condition2          0
# LandSlope           0
# Neighborhood        0
# ExterQual           0
# LotConfig           0
# Utilities           0
# LandContour         0
# LotShape            0
# Street              0
# MasVnrType          0
# BsmtQual            0
# ExterCond           0
# KitchenQual         0
# PoolQC              0
# PavedDrive          0
# GarageCond          0
# GarageQual          0
# GarageFinish        0
# GarageType          0
# Functional          0
# CentralAir          0
# Foundation          0
# HeatingQC           0
# Heating             0
# BsmtFinType2        0
# BsmtFinType1        0
# BsmtExposure        0
# BsmtCond            0
# ...

# %%
corr= num.corr()

# %%
corr['SalePrice'].sort_values(ascending = False).head(10)
